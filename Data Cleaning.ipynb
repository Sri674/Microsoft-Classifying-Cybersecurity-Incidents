# %%
import pandas as pd 

dft=pd.read_csv("train_dataset.csv") 
dft.head()
# Out:
#               Id  OrgId  IncidentId  AlertId                 Timestamp  \
# 0  1666447315115    395       23347    96321  2024-06-13T14:02:05.000Z
# 1   773094114354     56       11851     7912  2024-06-12T19:35:46.000Z
# 2  1443109014901      2       10006     7570  2024-06-06T19:09:18.000Z
# 3    85899348503      8       15327   257875  2024-06-02T23:30:59.000Z
# 4  1142461305553     38      288861   680262  2024-06-12T01:59:57.000Z
#
#    DetectorId  AlertTitle            Category MitreTechniques   IncidentGrade  \
# 0           6           5       InitialAccess           T1566   FalsePositive
# 1         853         270    CredentialAccess           T1110    TruePositive
# 2          15          13        Exfiltration             NaN  BenignPositive
# 3           3           4  SuspiciousActivity             NaN    TruePositive
# 4         182         153    CredentialAccess           T1528    TruePositive
#
#    ... ResourceType Roles OSFamily OSVersion  AntispamDirection  \
# ...

# %%
dft.dtypes
# Out:
# Id                      int64
# OrgId                   int64
# IncidentId              int64
# AlertId                 int64
# Timestamp              object
# DetectorId              int64
# AlertTitle              int64
# Category               object
# MitreTechniques        object
# IncidentGrade          object
# ActionGrouped          object
# ActionGranular         object
# EntityType             object
# EvidenceRole           object
# DeviceId                int64
# Sha256                  int64
# IpAddress               int64
# Url                     int64
# AccountSid              int64
# AccountUpn              int64
# AccountObjectId         int64
# AccountName             int64
# DeviceName              int64
# NetworkMessageId        int64
# EmailClusterId        float64
# RegistryKey             int64
# RegistryValueName       int64
# RegistryValueData       int64
# ApplicationId           int64
# ApplicationName         int64
# OAuthApplicationId      int64
# ...

# %%
dft.isnull().sum()
# Out:
# Id                          0
# OrgId                       0
# IncidentId                  0
# AlertId                     0
# Timestamp                   0
# DetectorId                  0
# AlertTitle                  0
# Category                    0
# MitreTechniques        837133
# IncidentGrade               0
# ActionGrouped         1499241
# ActionGranular        1499241
# EntityType                  0
# EvidenceRole                0
# DeviceId                    0
# Sha256                      0
# IpAddress                   0
# Url                         0
# AccountSid                  0
# AccountUpn                  0
# AccountObjectId             0
# AccountName                 0
# DeviceName                  0
# NetworkMessageId            0
# EmailClusterId        1485125
# RegistryKey                 0
# RegistryValueName           0
# RegistryValueData           0
# ApplicationId               0
# ApplicationName             0
# OAuthApplicationId          0
# ...

# %%
dft["MitreTechniques"].nunique()
# Out:
# 972

# %%
dft["MitreTechniques"]=dft["MitreTechniques"].fillna("Unknown")

# %%
dft.isnull().sum()
# Out:
# Id                          0
# OrgId                       0
# IncidentId                  0
# AlertId                     0
# Timestamp                   0
# DetectorId                  0
# AlertTitle                  0
# Category                    0
# MitreTechniques             0
# IncidentGrade               0
# ActionGrouped         1499241
# ActionGranular        1499241
# EntityType                  0
# EvidenceRole                0
# DeviceId                    0
# Sha256                      0
# IpAddress                   0
# Url                         0
# AccountSid                  0
# AccountUpn                  0
# AccountObjectId             0
# AccountName                 0
# DeviceName                  0
# NetworkMessageId            0
# EmailClusterId        1485125
# RegistryKey                 0
# RegistryValueName           0
# RegistryValueData           0
# ApplicationId               0
# ApplicationName             0
# OAuthApplicationId          0
# ...

# %%
dft.drop(columns=["ActionGrouped","ActionGranular","EmailClusterId","ThreatFamily","ResourceType","Roles","AntispamDirection"],inplace=True)

# %%
dft.isnull().sum()
# Out:
# Id                          0
# OrgId                       0
# IncidentId                  0
# AlertId                     0
# Timestamp                   0
# DetectorId                  0
# AlertTitle                  0
# Category                    0
# MitreTechniques             0
# IncidentGrade               0
# EntityType                  0
# EvidenceRole                0
# DeviceId                    0
# Sha256                      0
# IpAddress                   0
# Url                         0
# AccountSid                  0
# AccountUpn                  0
# AccountObjectId             0
# AccountName                 0
# DeviceName                  0
# NetworkMessageId            0
# RegistryKey                 0
# RegistryValueName           0
# RegistryValueData           0
# ApplicationId               0
# ApplicationName             0
# OAuthApplicationId          0
# FileName                    0
# FolderPath                  0
# ResourceIdName              0
# ...

# %%
import pandas as pd
pd.set_option("display.max_rows",None)
dft["SuspicionLevel"].value_counts()
# Out:
# SuspicionLevel
# Suspicious      211126
# Incriminated        73
# Name: count, dtype: int64

# %%
dft.dtypes
# Out:
# Id                     int64
# OrgId                  int64
# IncidentId             int64
# AlertId                int64
# Timestamp             object
# DetectorId             int64
# AlertTitle             int64
# Category              object
# MitreTechniques       object
# IncidentGrade         object
# EntityType            object
# EvidenceRole          object
# DeviceId               int64
# Sha256                 int64
# IpAddress              int64
# Url                    int64
# AccountSid             int64
# AccountUpn             int64
# AccountObjectId        int64
# AccountName            int64
# DeviceName             int64
# NetworkMessageId       int64
# RegistryKey            int64
# RegistryValueName      int64
# RegistryValueData      int64
# ApplicationId          int64
# ApplicationName        int64
# OAuthApplicationId     int64
# FileName               int64
# FolderPath             int64
# ResourceIdName         int64
# OSFamily               int64
# ...

# %%
import pandas as pd
pd.set_option("display.max_rows",None)
dft["LastVerdict"].value_counts()
# Out:
# LastVerdict
# Suspicious                                            205804
# Malicious                                              62743
# NoThreatsFound                                         60342
# DomainPII_50d8b4a941c26b89482c94ab324b5a274f9ced66        23
# DomainPII_9207384283ce115db5a590dd9ca5de21e5e99df2         8
# Name: count, dtype: int64

# %%
dft.drop(columns=["SuspicionLevel"], inplace=True)

# %%
dft.isnull().sum()
# Out:
# Id                          0
# OrgId                       0
# IncidentId                  0
# AlertId                     0
# Timestamp                   0
# DetectorId                  0
# AlertTitle                  0
# Category                    0
# MitreTechniques             0
# IncidentGrade               0
# EntityType                  0
# EvidenceRole                0
# DeviceId                    0
# Sha256                      0
# IpAddress                   0
# Url                         0
# AccountSid                  0
# AccountUpn                  0
# AccountObjectId             0
# AccountName                 0
# DeviceName                  0
# NetworkMessageId            0
# RegistryKey                 0
# RegistryValueName           0
# RegistryValueData           0
# ApplicationId               0
# ApplicationName             0
# OAuthApplicationId          0
# FileName                    0
# FolderPath                  0
# ResourceIdName              0
# ...

# %%
dft.drop(columns=["LastVerdict"], inplace=True)

# %%
dft.isnull().sum()
# Out:
# Id                    0
# OrgId                 0
# IncidentId            0
# AlertId               0
# Timestamp             0
# DetectorId            0
# AlertTitle            0
# Category              0
# MitreTechniques       0
# IncidentGrade         0
# EntityType            0
# EvidenceRole          0
# DeviceId              0
# Sha256                0
# IpAddress             0
# Url                   0
# AccountSid            0
# AccountUpn            0
# AccountObjectId       0
# AccountName           0
# DeviceName            0
# NetworkMessageId      0
# RegistryKey           0
# RegistryValueName     0
# RegistryValueData     0
# ApplicationId         0
# ApplicationName       0
# OAuthApplicationId    0
# FileName              0
# FolderPath            0
# ResourceIdName        0
# OSFamily              0
# OSVersion             0
# CountryCode           0
# State                 0
# City                  0
# dtype: int64

# %%
dft.head()
# Out:
#               Id  OrgId  IncidentId  AlertId                 Timestamp  \
# 0  1666447315115    395       23347    96321  2024-06-13T14:02:05.000Z
# 1   773094114354     56       11851     7912  2024-06-12T19:35:46.000Z
# 2  1443109014901      2       10006     7570  2024-06-06T19:09:18.000Z
# 3    85899348503      8       15327   257875  2024-06-02T23:30:59.000Z
# 4  1142461305553     38      288861   680262  2024-06-12T01:59:57.000Z
#
#    DetectorId  AlertTitle            Category MitreTechniques   IncidentGrade  \
# 0           6           5       InitialAccess           T1566   FalsePositive
# 1         853         270    CredentialAccess           T1110    TruePositive
# 2          15          13        Exfiltration         Unknown  BenignPositive
# 3           3           4  SuspiciousActivity         Unknown    TruePositive
# 4         182         153    CredentialAccess           T1528    TruePositive
#
#    ... ApplicationName OAuthApplicationId  FileName  FolderPath  \
# ...

# %%
dft.dtypes
# Out:
# Id                     int64
# OrgId                  int64
# IncidentId             int64
# AlertId                int64
# Timestamp             object
# DetectorId             int64
# AlertTitle             int64
# Category              object
# MitreTechniques       object
# IncidentGrade         object
# EntityType            object
# EvidenceRole          object
# DeviceId               int64
# Sha256                 int64
# IpAddress              int64
# Url                    int64
# AccountSid             int64
# AccountUpn             int64
# AccountObjectId        int64
# AccountName            int64
# DeviceName             int64
# NetworkMessageId       int64
# RegistryKey            int64
# RegistryValueName      int64
# RegistryValueData      int64
# ApplicationId          int64
# ApplicationName        int64
# OAuthApplicationId     int64
# FileName               int64
# FolderPath             int64
# ResourceIdName         int64
# OSFamily               int64
# ...

# %%
dft["Timestamp"]=pd.to_datetime(dft["Timestamp"])

# %%
dft['hour'] = dft['Timestamp'].dt.hour
dft['day'] = dft['Timestamp'].dt.day
dft['month'] = dft['Timestamp'].dt.month
dft['weekday'] = dft['Timestamp'].dt.weekday

# %%
dft.head()
# Out:
#               Id  OrgId  IncidentId  AlertId                 Timestamp  \
# 0  1666447315115    395       23347    96321 2024-06-13 14:02:05+00:00
# 1   773094114354     56       11851     7912 2024-06-12 19:35:46+00:00
# 2  1443109014901      2       10006     7570 2024-06-06 19:09:18+00:00
# 3    85899348503      8       15327   257875 2024-06-02 23:30:59+00:00
# 4  1142461305553     38      288861   680262 2024-06-12 01:59:57+00:00
#
#    DetectorId  AlertTitle            Category MitreTechniques   IncidentGrade  \
# 0           6           5       InitialAccess           T1566   FalsePositive
# 1         853         270    CredentialAccess           T1110    TruePositive
# 2          15          13        Exfiltration         Unknown  BenignPositive
# 3           3           4  SuspiciousActivity         Unknown    TruePositive
# 4         182         153    CredentialAccess           T1528    TruePositive
#
# ...

# %%
dft["hour"].unique()
# Out:
# array([14, 19, 23,  1,  9,  0,  2, 21, 17,  8, 12,  6, 22, 13, 16, 20,  3,
#        11, 18, 10,  5, 15,  7,  4])

# %%
dft["day"].unique()
# Out:
# array([13, 12,  6,  2, 29,  4, 11, 25, 24, 26,  7,  3,  8,  5, 31,  9, 22,
#        10, 14, 23, 16, 15, 27, 17, 30, 20, 21,  1, 28, 18, 19])

# %%
dft["month"].unique()
# Out:
# array([ 6,  5,  4,  3,  1,  2, 12, 11])

# %%
dft["weekday"].unique()
# Out:
# array([3, 2, 6, 1, 5, 4, 0])

# %%
dft.drop(columns=['Timestamp'],inplace=True)

# %%
dft.dtypes
# Out:
# Id                     int64
# OrgId                  int64
# IncidentId             int64
# AlertId                int64
# DetectorId             int64
# AlertTitle             int64
# Category              object
# MitreTechniques       object
# IncidentGrade         object
# EntityType            object
# EvidenceRole          object
# DeviceId               int64
# Sha256                 int64
# IpAddress              int64
# Url                    int64
# AccountSid             int64
# AccountUpn             int64
# AccountObjectId        int64
# AccountName            int64
# DeviceName             int64
# NetworkMessageId       int64
# RegistryKey            int64
# RegistryValueName      int64
# RegistryValueData      int64
# ApplicationId          int64
# ApplicationName        int64
# OAuthApplicationId     int64
# FileName               int64
# FolderPath             int64
# ResourceIdName         int64
# OSFamily               int64
# OSVersion              int64
# ...

# %%
dft["IncidentGrade"].value_counts()
# Out:
# IncidentGrade
# FalsePositive     500000
# TruePositive      500000
# BenignPositive    500000
# Name: count, dtype: int64

# %%
dft.drop(columns=["OrgId","EvidenceRole","Sha256","AccountUpn","AccountObjectId","RegistryValueName","RegistryValueData"],inplace=True)

# %%
dft.dtypes
# Out:
# Id                     int64
# IncidentId             int64
# AlertId                int64
# DetectorId             int64
# AlertTitle             int64
# Category              object
# MitreTechniques       object
# IncidentGrade         object
# EntityType            object
# DeviceId               int64
# IpAddress              int64
# Url                    int64
# AccountSid             int64
# AccountName            int64
# DeviceName             int64
# NetworkMessageId       int64
# RegistryKey            int64
# ApplicationId          int64
# ApplicationName        int64
# OAuthApplicationId     int64
# FileName               int64
# FolderPath             int64
# ResourceIdName         int64
# OSFamily               int64
# OSVersion              int64
# CountryCode            int64
# State                  int64
# City                   int64
# hour                   int32
# day                    int32
# month                  int32
# weekday                int32
# ...

# %%
dft.drop(columns=["OAuthApplicationId","ResourceIdName","State","City"],inplace=True)

# %%
dft.drop(columns=["AlertTitle","OSVersion"],inplace=True)

# %%
dft.shape
# Out:
# (1500000, 26)

# %%
dft.dtypes
# Out:
# Id                   int64
# IncidentId           int64
# AlertId              int64
# DetectorId           int64
# Category            object
# MitreTechniques     object
# IncidentGrade       object
# EntityType          object
# DeviceId             int64
# IpAddress            int64
# Url                  int64
# AccountSid           int64
# AccountName          int64
# DeviceName           int64
# NetworkMessageId     int64
# RegistryKey          int64
# ApplicationId        int64
# ApplicationName      int64
# FileName             int64
# FolderPath           int64
# OSFamily             int64
# CountryCode          int64
# hour                 int32
# day                  int32
# month                int32
# weekday              int32
# dtype: object

# %%
dft.to_csv("dft.csv",index=False)

# %%
import pandas as pd 

dft1=pd.read_csv("dft.csv") 
dft1.head()
# Out:
#               Id  IncidentId  AlertId  DetectorId            Category  \
# 0  1666447315115       23347    96321           6       InitialAccess
# 1   773094114354       11851     7912         853    CredentialAccess
# 2  1443109014901       10006     7570          15        Exfiltration
# 3    85899348503       15327   257875           3  SuspiciousActivity
# 4  1142461305553      288861   680262         182    CredentialAccess
#
#   MitreTechniques   IncidentGrade        EntityType  DeviceId  IpAddress  ...  \
# 0           T1566   FalsePositive              User     98799     360606  ...
# 1           T1110    TruePositive              User     98799     360606  ...
# 2         Unknown  BenignPositive       MailMessage     98799     360606  ...
# 3         Unknown    TruePositive           Machine        21     360606  ...
# 4           T1528    TruePositive  CloudApplication     98799     360606  ...
#
#    ApplicationId  ApplicationName  FileName  FolderPath  OSFamily  \
# ...

# %%
dft1.dtypes
# Out:
# Id                   int64
# IncidentId           int64
# AlertId              int64
# DetectorId           int64
# Category            object
# MitreTechniques     object
# IncidentGrade       object
# EntityType          object
# DeviceId             int64
# IpAddress            int64
# Url                  int64
# AccountSid           int64
# AccountName          int64
# DeviceName           int64
# NetworkMessageId     int64
# RegistryKey          int64
# ApplicationId        int64
# ApplicationName      int64
# FileName             int64
# FolderPath           int64
# OSFamily             int64
# CountryCode          int64
# hour                 int64
# day                  int64
# month                int64
# weekday              int64
# dtype: object

# %%
dft1["OSFamily"].value_counts()
# Out:
# OSFamily
# 5    1470871
# 0      28495
# 1        369
# 2        263
# 3          2
# Name: count, dtype: int64

# %%
dft1["OSFamily"]=dft1["OSFamily"].astype(str)

# %%
OS_Family_Mapping={
    "0":"Windows",
    "1":"Linux",
    "2":"macOS",
    "3":"Other",
    "5":"Unknown" 
} 

dft1["OSFamily"]=dft1["OSFamily"].map(OS_Family_Mapping) 

print(dft1["OSFamily"].value_counts())
# Out:
# OSFamily
# Unknown    1470871
# Windows      28495
# Linux          369
# macOS          263
# Other            2
# Name: count, dtype: int64

# %%
dft1.dtypes
# Out:
# Id                   int64
# IncidentId           int64
# AlertId              int64
# DetectorId           int64
# Category            object
# MitreTechniques     object
# IncidentGrade       object
# EntityType          object
# DeviceId             int64
# IpAddress            int64
# Url                  int64
# AccountSid           int64
# AccountName          int64
# DeviceName           int64
# NetworkMessageId     int64
# RegistryKey          int64
# ApplicationId        int64
# ApplicationName      int64
# FileName             int64
# FolderPath           int64
# OSFamily            object
# CountryCode          int64
# hour                 int64
# day                  int64
# month                int64
# weekday              int64
# dtype: object

# %%
dft1.head()
# Out:
#               Id  IncidentId  AlertId  DetectorId            Category  \
# 0  1666447315115       23347    96321           6       InitialAccess
# 1   773094114354       11851     7912         853    CredentialAccess
# 2  1443109014901       10006     7570          15        Exfiltration
# 3    85899348503       15327   257875           3  SuspiciousActivity
# 4  1142461305553      288861   680262         182    CredentialAccess
#
#   MitreTechniques   IncidentGrade        EntityType  DeviceId  IpAddress  ...  \
# 0           T1566   FalsePositive              User     98799     360606  ...
# 1           T1110    TruePositive              User     98799     360606  ...
# 2         Unknown  BenignPositive       MailMessage     98799     360606  ...
# 3         Unknown    TruePositive           Machine        21     360606  ...
# 4           T1528    TruePositive  CloudApplication     98799     360606  ...
#
#    ApplicationId  ApplicationName  FileName  FolderPath  OSFamily  \
# ...

# %%
dft1.dtypes
# Out:
# Id                   int64
# IncidentId           int64
# AlertId              int64
# DetectorId           int64
# Category            object
# MitreTechniques     object
# IncidentGrade       object
# EntityType          object
# DeviceId             int64
# IpAddress            int64
# Url                  int64
# AccountSid           int64
# AccountName          int64
# DeviceName           int64
# NetworkMessageId     int64
# RegistryKey          int64
# ApplicationId        int64
# ApplicationName      int64
# FileName             int64
# FolderPath           int64
# OSFamily            object
# CountryCode          int64
# hour                 int64
# day                  int64
# month                int64
# weekday              int64
# dtype: object

# %%
dft1.drop(columns=["MitreTechniques"],inplace=True)

# %%
dft1.columns
# Out:
# Index(['Id', 'IncidentId', 'AlertId', 'DetectorId', 'Category',
#        'IncidentGrade', 'EntityType', 'DeviceId', 'IpAddress', 'Url',
#        'AccountSid', 'AccountName', 'DeviceName', 'NetworkMessageId',
#        'RegistryKey', 'ApplicationId', 'ApplicationName', 'FileName',
#        'FolderPath', 'OSFamily', 'CountryCode', 'hour', 'day', 'month',
#        'weekday'],
#       dtype='object')

# %%
dft1.dtypes
# Out:
# Id                   int64
# IncidentId           int64
# AlertId              int64
# DetectorId           int64
# Category            object
# IncidentGrade       object
# EntityType          object
# DeviceId             int64
# IpAddress            int64
# Url                  int64
# AccountSid           int64
# AccountName          int64
# DeviceName           int64
# NetworkMessageId     int64
# RegistryKey          int64
# ApplicationId        int64
# ApplicationName      int64
# FileName             int64
# FolderPath           int64
# OSFamily            object
# CountryCode          int64
# hour                 int64
# day                  int64
# month                int64
# weekday              int64
# dtype: object

# %%
dft1.drop(columns=["Id","IncidentId","AlertId","DetectorId","NetworkMessageId"],inplace=True)

# %%
dft1.columns
# Out:
# Index(['Category', 'IncidentGrade', 'EntityType', 'DeviceId', 'IpAddress',
#        'Url', 'AccountSid', 'AccountName', 'DeviceName', 'RegistryKey',
#        'ApplicationId', 'ApplicationName', 'FileName', 'FolderPath',
#        'OSFamily', 'CountryCode', 'hour', 'day', 'month', 'weekday'],
#       dtype='object')

# %%
dft1.dtypes
# Out:
# Category           object
# IncidentGrade      object
# EntityType         object
# DeviceId            int64
# IpAddress           int64
# Url                 int64
# AccountSid          int64
# AccountName         int64
# DeviceName          int64
# RegistryKey         int64
# ApplicationId       int64
# ApplicationName     int64
# FileName            int64
# FolderPath          int64
# OSFamily           object
# CountryCode         int64
# hour                int64
# day                 int64
# month               int64
# weekday             int64
# dtype: object

# %%
dft1.head()
# Out:
#              Category   IncidentGrade        EntityType  DeviceId  IpAddress  \
# 0       InitialAccess   FalsePositive              User     98799     360606
# 1    CredentialAccess    TruePositive              User     98799     360606
# 2        Exfiltration  BenignPositive       MailMessage     98799     360606
# 3  SuspiciousActivity    TruePositive           Machine        21     360606
# 4    CredentialAccess    TruePositive  CloudApplication     98799     360606
#
#       Url  AccountSid  AccountName  DeviceName  RegistryKey  ApplicationId  \
# 0  160396       12578        13834      153085         1631           2251
# 1  160396      145718       139254      153085         1631           2251
# 2  160396      441377       453297      153085         1631           2251
# 3  160396      441377       453297          26         1631           2251
# 4  160396      441377       453297      153085         1631              1
#
# ...

# %%
dft1["CountryCode"].unique()
# Out:
# array([242,   2,   6,   1,  32,   0,   5,  22,   4,  37,   3,  42,   7,
#         20,  19,  11,  50,  31,  33,   8,  18,  56,  13,  76,  21,  63,
#         17,  29,  23,  24,  26,  16,  40,  65,  25,  81,  10,  28,   9,
#         14,  12,  38,  59,  15,  72,  61,  44,  36,  34,  52,  39,  82,
#         27,  54, 127,  41,  57,  48,  62,  35,  53,  45, 137, 110,  51,
#         64,  75,  30,  43,  60,  73, 107,  58,  46,  55,  47,  74,  49,
#         78,  91,  70,  79, 144,  71,  66, 125,  77, 117,  68,  67, 112,
#         90, 134,  80, 104,  83,  69,  92, 188, 184, 170,  95,  84, 123,
#        150, 101,  88,  94,  97, 140, 105, 102,  89, 141,  85, 106, 111,
#         96,  98,  86, 154,  93, 142, 108, 146, 135, 118, 103, 122, 164,
#         99, 132,  87, 173, 100, 126, 116, 121, 131, 230, 136, 124, 158,
#        172, 114, 119, 189, 151, 186, 167, 200, 161, 153, 237, 239, 162,
#        115, 130, 128, 138, 155, 148, 185, 149, 157, 147, 182, 109, 160,
# ...

# %%
dft1.dtypes
# Out:
# Category           object
# IncidentGrade      object
# EntityType         object
# DeviceId            int64
# IpAddress           int64
# Url                 int64
# AccountSid          int64
# AccountName         int64
# DeviceName          int64
# RegistryKey         int64
# ApplicationId       int64
# ApplicationName     int64
# FileName            int64
# FolderPath          int64
# OSFamily           object
# CountryCode         int64
# hour                int64
# day                 int64
# month               int64
# weekday             int64
# dtype: object

# %%
dft1.head()
# Out:
#              Category   IncidentGrade        EntityType  DeviceId  IpAddress  \
# 0       InitialAccess   FalsePositive              User     98799     360606
# 1    CredentialAccess    TruePositive              User     98799     360606
# 2        Exfiltration  BenignPositive       MailMessage     98799     360606
# 3  SuspiciousActivity    TruePositive           Machine        21     360606
# 4    CredentialAccess    TruePositive  CloudApplication     98799     360606
#
#       Url  AccountSid  AccountName  DeviceName  RegistryKey  ApplicationId  \
# 0  160396       12578        13834      153085         1631           2251
# 1  160396      145718       139254      153085         1631           2251
# 2  160396      441377       453297      153085         1631           2251
# 3  160396      441377       453297          26         1631           2251
# 4  160396      441377       453297      153085         1631              1
#
# ...

# %%
dft1.shape
# Out:
# (1500000, 20)

# %%
dft1.to_csv("dft1.csv",index=False)

# %%
                             #FEATURE IMPORTANCE


import pandas as pd 
from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import LabelEncoder,StandardScaler 
from sklearn.ensemble import RandomForestClassifier 
import matplotlib.pyplot as plt 


Categorical_columns=['Category','IncidentGrade','EntityType','OSFamily'] 

numerical_columns= ['DeviceId', 'IpAddress', 'Url', 'AccountSid', 'AccountName', 'DeviceName', 
                  'RegistryKey', 'ApplicationId', 'ApplicationName', 'FileName', 'FolderPath', 
                  'CountryCode'] 

label_encoder=LabelEncoder() 

for col in Categorical_columns:
    dft1[col]=label_encoder.fit_transform(dft1[col])  

scaler=StandardScaler() 

dft1[numerical_columns]=scaler.fit_transform(dft1[numerical_columns])  


X=dft1.drop(columns=["IncidentGrade"]) 
y=dft1["IncidentGrade"]  

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42) 

rf_model=RandomForestClassifier(n_estimators=100,random_state=42) 

rf_model.fit(X_train,y_train)  

importances=rf_model.feature_importances_

feature_importance_df = pd.DataFrame({
    'Feature': X_train.columns,
    'Importance': importances
})

feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)


feature_importance_df
# Out:
#             Feature  Importance
# 3         IpAddress    0.153196
# 15             hour    0.126083
# 5        AccountSid    0.110816
# 0          Category    0.101126
# 6       AccountName    0.098392
# 16              day    0.070304
# 1        EntityType    0.066988
# 4               Url    0.054429
# 14      CountryCode    0.045388
# 11         FileName    0.044992
# 7        DeviceName    0.034107
# 18          weekday    0.030867
# 12       FolderPath    0.027726
# 2          DeviceId    0.015250
# 17            month    0.005653
# 10  ApplicationName    0.005340
# 9     ApplicationId    0.004739
# 8       RegistryKey    0.002355
# 13         OSFamily    0.002250
